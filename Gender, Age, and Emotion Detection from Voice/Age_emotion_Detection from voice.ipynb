# %% [markdown]
# ## About Dataset
#
# <b>Context:</b>
#
# Our target was to predict gender, age, and emotion from audio. We found audio labeled datasets on Mozilla and RAVDESS. So by using R programming language, 20 statistical features were extracted and then after adding the labels, these datasets were formed. Audio files were collected from "Mozilla Common Voice" and “Ryerson AudioVisual Database of Emotional Speech and Song (RAVDESS)”.
#
# <b>Content:</b>
#
# Datasets contain 20 feature columns and 1 column for denoting the label. The 20 statistical features were extracted through the Frequency Spectrum Analysis using R programming Language. They are:
#
# <pre>
# 1) <b>meanfreq</b>   - The mean frequency (kHz) is a pitch measure that assesses the center of the distribution of power across frequencies.
# 2) <b>sd</b>         - The standard deviation of frequency is a statistical measure that describes a dataset’s dispersion relative to its mean and is calculated as the variance’s square root.
# 3) <b>median</b>     - The median frequency (kHz) is the middle number in the sorted, ascending, or descending list of numbers.
# 4) <b>Q25</b>        - The first quartile (in kHz), referred to as Q1, is the median of the lower half of the data set. This means that about 25 percent of the data set numbers are below Q1, and about 75 percent are above Q1.
# 5) <b>Q75</b>        - The third quartile (in kHz), referred to as Q3, is the central point between the median and the highest distributions.
# 6) <b>IQR</b>        - The interquartile range (in kHz) is a measure of statistical dispersion, equal to the difference between the 75th and 25th percentiles or between upper and lower quartiles.
# 7) <b>skew</b>       - The skewness is the degree of distortion from the normal distribution. It measures the lack of symmetry in the data distribution.
# 8) <b>kurt</b>       - The kurtosis is a statistical measure that determines how much the tails of the distribution vary from the tails of a normal distribution. It is actually the measure of outliers present in the data distribution.
# 9) <b>sp.ent</b>     - The spectral entropy is a measure of signal irregularity that sums up the normalized signal’s spectral power.
# 10) <b>sfm</b>       - The spectral flatness or tonality coefficient, also known as Wiener entropy, is a measure used for digital signal processing to characterize an audio spectrum. Spectral flatness is usually measured in decibels, which, instead of being noise-like, offers a way to calculate how tone-like a sound is.
# 11) <b>mode</b>      - The mode frequency is the most frequently observed value in a data set.
# 12) <b>centroid</b>  - The spectral centroid is a metric used to describe a spectrum in digital signal processing. It means where the spectrum’s center of mass is centered.
# 13) <b>meanfun</b>   - The meanfun is the average of the fundamental frequency measured across the acoustic signal.
# 14) <b>minfun</b>    - The minfun is the minimum fundamental frequency measured across the acoustic signal.
# 15) <b>maxfun</b>    - The maxfun is the maximum fundamental frequency measured across the acoustic signal.
# 16) <b>meandom</b>   - The meandom is the average of the dominant frequency measured across the acoustic signal.
# 17) <b>mindom</b>    - The mindom is the minimum of the dominant frequency measured across the acoustic signal.
# 18) <b>maxdom</b>    - The maxdom is the maximum of the dominant frequency measured across the acoustic signal.
# 19) <b>dfrange</b>   - The dfrange is the range of the dominant frequency measured across the acoustic signal.
# 20) <b>modindx</b>   - the modindx is the modulation index, which calculates the degree of frequency modulation expressed numerically as the ratio of the frequency deviation to the frequency of the modulating signal for a pure tone modulation.
# </pre>

# %%
import pandas as pd

# %%
df_age = pd.read_csv('D:\Imam\Belajar\Python\Data_Science\Gender, Age, and Emotion Detection from Voice\cleaned_age.csv', sep =',')
df_emotion = pd.read_csv('D:\Imam\Belajar\Python\Data_Science\Gender, Age, and Emotion Detection from Voice\cleaned_emotion.csv', sep =',')

# %%
df_age
# Out:
#       Unnamed: 0.1  Unnamed: 0  meanfreq        sd    median       Q25  \
# 0               66          67  0.133338  0.069304  0.107668  0.089192
# 1               84          85  0.137433  0.058518  0.112037  0.092841
# 2               85          86  0.142227  0.065447  0.112242  0.093455
# 3               87          88  0.133325  0.072849  0.113360  0.082861
# 4               88          89  0.130487  0.070407  0.113418  0.076098
# ...            ...         ...       ...       ...       ...       ...
# 4356          6220        6221  0.241377  0.039956  0.252299  0.225070
# 4357          6222        6223  0.235059  0.053056  0.252532  0.231392
# 4358          6224        6225  0.230992  0.053711  0.252760  0.223666
# 4359          6230        6231  0.240334  0.044747  0.253897  0.233837
# 4360          6235        6236  0.227517  0.059336  0.257051  0.198797
#
#            Q75       IQR      skew       kurt  ...  centroid   meanfun  \
# 0     0.195267  0.106075  3.043456  13.694173  ...  0.133338  0.121968
# 1     0.200079  0.107238  2.807995  12.776650  ...  0.137433  0.111204
# 2     0.202909  0.109455  2.380899   9.942833  ...  0.142227  0.118711
# 3     0.203753  0.120892  1.904123   7.799218  ...  0.133325  0.116200
# 4     0.196188  0.120089  1.820873   8.561101  ...  0.130487  0.114802
# ...        ...       ...       ...        ...  ...       ...       ...
# 4356  0.269297  0.044227  2.730197  11.467950  ...  0.241377  0.176361
# 4357  0.264468  0.033077  2.869390  12.009156  ...  0.235059  0.120552
# 4358  0.265731  0.042065  3.277391  15.202833  ...  0.230992  0.162745
# 4359  0.265619  0.031782  2.826720  11.350446  ...  0.240334  0.134127
# 4360  0.267371  0.068574  3.287888  14.553146  ...  0.227517  0.121157
#
#         minfun    maxfun   meandom  mindom     maxdom    dfrange   modindx  \
# 0     0.047337  0.277457  0.822656  0.0000   4.687500   4.687500  0.076296
# 1     0.047151  0.277457  1.313384  0.0000   6.046875   6.046875  0.135811
# 2     0.047013  0.275862  0.593750  0.0000   6.539062   6.539062  0.096102
# 3     0.047105  0.279070  0.424922  0.0000   5.812500   5.812500  0.081880
# 4     0.047151  0.279070  0.198070  0.0000   1.078125   1.078125  0.131579
# ...        ...       ...       ...     ...        ...        ...       ...
# 4356  0.047666  0.279070  1.224946  0.0000   6.140625   6.140625  0.093181
# 4357  0.047572  0.274286  1.103427  0.0000  10.382812  10.382812  0.056716
# 4358  0.047059  0.277457  1.297944  0.1875  11.812500  11.625000  0.081470
# 4359  0.046967  0.271186  0.528390  0.0000   3.187500   3.187500  0.065266
# 4360  0.047105  0.279070  0.974657  0.0000  10.078125  10.078125  0.064763
#
#         label
# 0       young
# 1       young
# 2     matured
# 3       young
# 4     matured
# ...       ...
# 4356      old
# 4357  matured
# 4358    young
# 4359      old
# 4360    young
#
# [4361 rows x 23 columns]

# %%
df_emotion
# Out:
#      Unnamed: 0.1  Unnamed: 0     X  meanfreq        sd    median       Q25  \
# 0               0           1     1  0.181338  0.060495  0.187476  0.126197
# 1               1           2     2  0.186897  0.062260  0.195070  0.130847
# 2               2           3     3  0.189102  0.062901  0.204945  0.131422
# 3               4           5     5  0.183036  0.060051  0.174115  0.129949
# 4               5           6     6  0.168793  0.057910  0.156266  0.116783
# ..            ...         ...   ...       ...       ...       ...       ...
# 904          1243        1244  1436  0.244013  0.035477  0.254385  0.229653
# 905          1244        1245  1437  0.235383  0.045303  0.248974  0.220745
# 906          1245        1246  1438  0.231211  0.044793  0.234847  0.221477
# 907          1246        1247  1439  0.213587  0.082267  0.249435  0.207680
# 908          1247        1248  1440  0.212537  0.078746  0.245034  0.209794
#
#           Q75       IQR      skew  ...  centroid   meanfun    minfun  \
# 0    0.233586  0.107389  0.869088  ...  0.181338  0.137742  0.023022
# 1    0.243987  0.113140  1.191767  ...  0.186897  0.121811  0.018412
# 2    0.249978  0.118556  1.312690  ...  0.189102  0.123758  0.083333
# 3    0.236967  0.107017  1.096409  ...  0.183036  0.128469  0.044693
# 4    0.216326  0.099543  1.386837  ...  0.168793  0.109720  0.022472
# ..        ...       ...       ...  ...       ...       ...       ...
# 904  0.265573  0.035920  2.214752  ...  0.244013  0.202433  0.028829
# 905  0.264233  0.043488  2.474743  ...  0.235383  0.189293  0.031250
# 906  0.262090  0.040613  2.607668  ...  0.231211  0.171805  0.022346
# 907  0.268538  0.060858  3.460579  ...  0.213587  0.155277  0.020592
# 908  0.264031  0.054238  2.563983  ...  0.212537  0.162938  0.024845
#
#        maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# 0    0.271186  0.777344  0.085938  6.226562  6.140625  0.116586    sad
# 1    0.271186  0.930339  0.085938  4.000000  3.914062  0.144983    sad
# 2    0.262295  0.332386  0.085938  0.625000  0.539062  0.334783    sad
# 3    0.258065  1.012019  0.085938  5.468750  5.382812  0.304910    sad
# 4    0.235294  0.228795  0.093750  0.750000  0.656250  0.306777    sad
# ..        ...       ...       ...       ...       ...       ...    ...
# 904  0.271186  0.616536  0.210938  1.609375  1.398438  0.281869  happy
# 905  0.275862  1.115723  0.265625  5.500000  5.234375  0.167861  happy
# 906  0.275862  1.070801  0.265625  4.554688  4.289062  0.214936  happy
# 907  0.275862  1.724888  0.273438  6.812500  6.539062  0.238857  happy
# 908  0.258065  0.915625  0.000000  6.281250  6.281250  0.193141  happy
#
# [909 rows x 24 columns]

# %%
df_age.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis = 1, inplace = True)
df_emotion.drop(['Unnamed: 0.1', 'Unnamed: 0', 'X'], axis = 1, inplace = True)

# %% [markdown]
# ## Data df_age

# %%
pd.set_option('display.float_format', '{:.8f}'.format)
df_age
# Out:
#        meanfreq         sd     median        Q25        Q75        IQR  \
# 0    0.13333790 0.06930381 0.10766780 0.08919226 0.19526735 0.10607508
# 1    0.13743331 0.05851825 0.11203692 0.09284113 0.20007910 0.10723797
# 2    0.14222665 0.06544671 0.11224242 0.09345454 0.20290909 0.10945455
# 3    0.13332474 0.07284877 0.11335958 0.08286089 0.20375328 0.12089239
# 4    0.13048690 0.07040655 0.11341772 0.07609829 0.19618764 0.12008935
# ...         ...        ...        ...        ...        ...        ...
# 4356 0.24137700 0.03995634 0.25229904 0.22507026 0.26929736 0.04422709
# 4357 0.23505927 0.05305562 0.25253210 0.23139188 0.26446841 0.03307653
# 4358 0.23099171 0.05371050 0.25275976 0.22366645 0.26573130 0.04206486
# 4359 0.24033406 0.04474657 0.25389728 0.23383686 0.26561934 0.03178248
# 4360 0.22751715 0.05933560 0.25705141 0.19879728 0.26737148 0.06857420
#
#            skew        kurt     sp.ent        sfm  ...   centroid    meanfun  \
# 0    3.04345602 13.69417310 0.92951218 0.62787220  ... 0.13333790 0.12196788
# 1    2.80799517 12.77665008 0.91107951 0.47817510  ... 0.13743331 0.11120399
# 2    2.38089876  9.94283251 0.93603996 0.55727602  ... 0.14222665 0.11871123
# 3    1.90412319  7.79921795 0.95836176 0.70827852  ... 0.13332474 0.11620031
# 4    1.82087260  8.56110114 0.96956822 0.77848865  ... 0.13048690 0.11480236
# ...         ...         ...        ...        ...  ...        ...        ...
# 4356 2.73019654 11.46795006 0.84722045 0.18363090  ... 0.24137700 0.17636093
# 4357 2.86938984 12.00915623 0.85978375 0.30468593  ... 0.23505927 0.12055205
# 4358 3.27739090 15.20283348 0.86199483 0.31452789  ... 0.23099171 0.16274457
# 4359 2.82672040 11.35044647 0.85052725 0.23058845  ... 0.24033406 0.13412684
# 4360 3.28788754 14.55314623 0.85879672 0.28542534  ... 0.22751715 0.12115704
#
#          minfun     maxfun    meandom     mindom      maxdom     dfrange  \
# 0    0.04733728 0.27745665 0.82265625 0.00000000  4.68750000  4.68750000
# 1    0.04715128 0.27745665 1.31338443 0.00000000  6.04687500  6.04687500
# 2    0.04701273 0.27586207 0.59375000 0.00000000  6.53906250  6.53906250
# 3    0.04710500 0.27906977 0.42492188 0.00000000  5.81250000  5.81250000
# 4    0.04715128 0.27906977 0.19806985 0.00000000  1.07812500  1.07812500
# ...         ...        ...        ...        ...         ...         ...
# 4356 0.04766634 0.27906977 1.22494612 0.00000000  6.14062500  6.14062500
# 4357 0.04757185 0.27428571 1.10342685 0.00000000 10.38281250 10.38281250
# 4358 0.04705882 0.27745665 1.29794408 0.18750000 11.81250000 11.62500000
# 4359 0.04696673 0.27118644 0.52839007 0.00000000  3.18750000  3.18750000
# 4360 0.04710500 0.27906977 0.97465701 0.00000000 10.07812500 10.07812500
#
#         modindx    label
# 0    0.07629630    young
# 1    0.13581091    young
# 2    0.09610215  matured
# 3    0.08187953    young
# 4    0.13157895  matured
# ...         ...      ...
# 4356 0.09318066      old
# 4357 0.05671558  matured
# 4358 0.08146994    young
# 4359 0.06526611      old
# 4360 0.06476329    young
#
# [4361 rows x 21 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
categorial = df_age.columns.drop(['label'])
fig,ax = plt.subplots(ncols = 5, nrows = 4,
                     figsize = (15,10))
fig.subplots_adjust(hspace = 0.5)
ax = ax.flatten()

for i,col in enumerate(categorial):
    
    sns.histplot(data = df_age,
                x = col,
                kde = True,
                color = 'green',
                ax = ax[i])
    ax[i].set_title(col)
    ax[i].set_xlabel('')
    
    if i % 3 != 0:
        ax[i].set_ylabel('')
        
fig.suptitle('Histogram of Objective Value', fontsize = 15, weight = 'bold')
# Out:
# Text(0.5, 0.98, 'Histogram of Objective Value')

# %%
numberical = df_age.columns.drop(['label'])

fig,ax = plt.subplots(ncols = 5, nrows = 4,
                     figsize = (24,16))
fig.subplots_adjust(hspace = 0.5)
ax = ax.flatten()

for i,col in enumerate(numberical):
    
    sns.boxplot(data = df_age,
                x = 'label',
                y = col,
                ax = ax[i],
                palette = 'summer')
    ax[i].set_title(col)
    ax[i].set_xlabel('')
    
    if i % 2 != 0:
        ax[i].set_ylabel('')
        
fig.suptitle('Boxplot of Numeric Value', fontsize = 15, weight = 'bold')
# Out:
# Text(0.5, 0.98, 'Boxplot of Numeric Value')

# %%
df_age.columns
# Out:
# Index(['meanfreq', 'sd', 'median', 'Q25', 'Q75', 'IQR', 'skew', 'kurt',
#        'sp.ent', 'sfm', 'mode', 'centroid', 'meanfun', 'minfun', 'maxfun',
#        'meandom', 'mindom', 'maxdom', 'dfrange', 'modindx', 'label'],
#       dtype='object')

# %%
df_age.drop(['mindom'], axis = 1, inplace = True)

# %%
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyClassifier

# %%
X = df_age.drop(['label'], axis = 1)
y = df_age['label']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 64, train_size = 0.8)

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
LF = LazyClassifier()

model_LF, predictions = LF.fit(X_train, X_test, y_train, y_test)
print(model_LF)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:13<00:00,  2.14it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# RandomForestClassifier             0.59               0.52    None      0.58
# LGBMClassifier                     0.57               0.52    None      0.57
# ExtraTreesClassifier               0.57               0.51    None      0.56
# BaggingClassifier                  0.54               0.49    None      0.53
# KNeighborsClassifier               0.51               0.47    None      0.51
# SVC                                0.54               0.46    None      0.52
# LabelSpreading                     0.47               0.45    None      0.47
# LabelPropagation                   0.47               0.45    None      0.47
# AdaBoostClassifier                 0.51               0.44    None      0.50
# ExtraTreeClassifier                0.47               0.44    None      0.47
# DecisionTreeClassifier             0.46               0.43    None      0.46
# NearestCentroid                    0.36               0.40    None      0.35
# QuadraticDiscriminantAnalysis      0.46               0.39    None      0.45
# SGDClassifier                      0.45               0.38    None      0.44
# PassiveAggressiveClassifier        0.41               0.37    None      0.41
# LinearDiscriminantAnalysis         0.48               0.37    None      0.43
# LogisticRegression                 0.48               0.37    None      0.43
# RidgeClassifierCV                  0.48               0.37    None      0.43
# LinearSVC                          0.48               0.37    None      0.43
# RidgeClassifier                    0.47               0.37    None      0.43
# CalibratedClassifierCV             0.47               0.37    None      0.42
# GaussianNB                         0.46               0.37    None      0.44
# Perceptron                         0.39               0.36    None      0.39
# BernoulliNB                        0.45               0.35    None      0.41
# DummyClassifier                    0.44               0.33    None      0.26
#
#                                Time Taken
# Model
# RandomForestClassifier               2.12
# LGBMClassifier                       0.62
# ExtraTreesClassifier                 0.68
# BaggingClassifier                    0.85
# KNeighborsClassifier                 0.15
# SVC                                  1.29
# LabelSpreading                       0.94
# LabelPropagation                     0.69
# AdaBoostClassifier                   0.80
# ExtraTreeClassifier                  0.02
# DecisionTreeClassifier               0.11
# NearestCentroid                      0.02
# QuadraticDiscriminantAnalysis        0.03
# SGDClassifier                        0.08
# PassiveAggressiveClassifier          0.03
# LinearDiscriminantAnalysis           0.04
# LogisticRegression                   0.11
# RidgeClassifierCV                    0.03
# LinearSVC                            0.94
# RidgeClassifier                      0.03
# CalibratedClassifierCV               3.87
# GaussianNB                           0.02
# Perceptron                           0.03
# BernoulliNB                          0.03
# DummyClassifier                      0.02

# %% [markdown]
# ## Data df_emotion

# %%
pd.set_option('display.float_format', '{:.8f}'.format)

# %%
df_emotion
# Out:
#       meanfreq         sd     median        Q25        Q75        IQR  \
# 0   0.18133810 0.06049512 0.18747562 0.12619718 0.23358613 0.10738895
# 1   0.18689739 0.06226033 0.19506967 0.13084673 0.24398714 0.11314041
# 2   0.18910214 0.06290128 0.20494529 0.13142232 0.24997812 0.11855580
# 3   0.18303606 0.06005126 0.17411527 0.12994944 0.23696663 0.10701719
# 4   0.16879306 0.05791022 0.15626614 0.11678252 0.21632572 0.09954320
# ..         ...        ...        ...        ...        ...        ...
# 904 0.24401260 0.03547650 0.25438486 0.22965300 0.26557308 0.03592008
# 905 0.23538334 0.04530260 0.24897366 0.22074478 0.26423252 0.04348774
# 906 0.23121091 0.04479299 0.23484685 0.22147748 0.26209009 0.04061261
# 907 0.21358741 0.08226703 0.24943470 0.20768031 0.26853801 0.06085770
# 908 0.21253679 0.07874586 0.24503442 0.20979351 0.26403147 0.05423795
#
#           skew        kurt     sp.ent        sfm  ...   centroid    meanfun  \
# 0   0.86908780  2.86371689 0.92356626 0.30721956  ... 0.18133810 0.13774222
# 1   1.19176743  3.87865036 0.91884764 0.29885933  ... 0.18689739 0.12181136
# 2   1.31269028  4.58999505 0.91951906 0.31306859  ... 0.18910214 0.12375790
# 3   1.09640870  3.68099538 0.92136142 0.32929538  ... 0.18303606 0.12846933
# 4   1.38683675  5.03174390 0.92623769 0.33704677  ... 0.16879306 0.10971989
# ..         ...         ...        ...        ...  ...        ...        ...
# 904 2.21475227  7.56505183 0.82187418 0.13693314  ... 0.24401260 0.20243265
# 905 2.47474271  9.95901930 0.84810904 0.23695732  ... 0.23538334 0.18929334
# 906 2.60766783 10.69882149 0.84870220 0.24199829  ... 0.23121091 0.17180497
# 907 3.46057904 18.03461359 0.88254350 0.42539413  ... 0.21358741 0.15527709
# 908 2.56398349 10.39288545 0.88738920 0.40499328  ... 0.21253679 0.16293842
#
#         minfun     maxfun    meandom     mindom     maxdom    dfrange  \
# 0   0.02302158 0.27118644 0.77734375 0.08593750 6.22656250 6.14062500
# 1   0.01841197 0.27118644 0.93033854 0.08593750 4.00000000 3.91406250
# 2   0.08333333 0.26229508 0.33238636 0.08593750 0.62500000 0.53906250
# 3   0.04469274 0.25806452 1.01201923 0.08593750 5.46875000 5.38281250
# 4   0.02247191 0.23529412 0.22879464 0.09375000 0.75000000 0.65625000
# ..         ...        ...        ...        ...        ...        ...
# 904 0.02882883 0.27118644 0.61653646 0.21093750 1.60937500 1.39843750
# 905 0.03125000 0.27586207 1.11572266 0.26562500 5.50000000 5.23437500
# 906 0.02234637 0.27586207 1.07080078 0.26562500 4.55468750 4.28906250
# 907 0.02059202 0.27586207 1.72488839 0.27343750 6.81250000 6.53906250
# 908 0.02484472 0.25806452 0.91562500 0.00000000 6.28125000 6.28125000
#
#        modindx  label
# 0   0.11658570    sad
# 1   0.14498276    sad
# 2   0.33478261    sad
# 3   0.30491050    sad
# 4   0.30677656    sad
# ..         ...    ...
# 904 0.28186897  happy
# 905 0.16786070  happy
# 906 0.21493625  happy
# 907 0.23885672  happy
# 908 0.19314144  happy
#
# [909 rows x 21 columns]

# %%
categorial = df_emotion.columns.drop(['label'])
fig,ax = plt.subplots(ncols = 5, nrows = 4,
                     figsize = (15,10))
fig.subplots_adjust(hspace = 0.5)
ax = ax.flatten()

for i,col in enumerate(categorial):
    
    sns.histplot(data = df_emotion,
                x = col,
                kde = True,
                color = 'green',
                ax = ax[i])
    ax[i].set_title(col)
    ax[i].set_xlabel('')
    
    if i % 3 != 0:
        ax[i].set_ylabel('')
        
fig.suptitle('Histogram of Objective Value', fontsize = 15, weight = 'bold')
# Out:
# Text(0.5, 0.98, 'Histogram of Objective Value')

# %%
numberical = df_emotion.columns.drop(['label'])

fig,ax = plt.subplots(ncols = 5, nrows = 4,
                     figsize = (24,16))
fig.subplots_adjust(hspace = 0.5)
ax = ax.flatten()

for i,col in enumerate(numberical):
    
    sns.boxplot(data = df_emotion,
                x = 'label',
                y = col,
                ax = ax[i],
                palette = 'summer')
    ax[i].set_title(col)
    ax[i].set_xlabel('')
    
    if i % 2 != 0:
        ax[i].set_ylabel('')
        
fig.suptitle('Boxplot of Numeric Value', fontsize = 15, weight = 'bold')
# Out:
# Text(0.5, 0.98, 'Boxplot of Numeric Value')

# %%
X = df_emotion.drop(['label'], axis = 1)
y = df_emotion['label']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 64, train_size = 0.8)

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
LF = LazyClassifier()

model_LF, predictions = LF.fit(X_train, X_test, y_train, y_test)
print(model_LF)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:03<00:00,  9.24it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.61               0.61    None      0.61
# NuSVC                              0.60               0.60    None      0.59
# RandomForestClassifier             0.59               0.59    None      0.59
# SGDClassifier                      0.58               0.58    None      0.58
# ExtraTreesClassifier               0.58               0.58    None      0.58
# KNeighborsClassifier               0.56               0.56    None      0.56
# SVC                                0.55               0.55    None      0.55
# LinearDiscriminantAnalysis         0.55               0.55    None      0.55
# LogisticRegression                 0.55               0.55    None      0.55
# CalibratedClassifierCV             0.55               0.55    None      0.55
# RidgeClassifierCV                  0.55               0.55    None      0.55
# RidgeClassifier                    0.55               0.55    None      0.55
# AdaBoostClassifier                 0.55               0.55    None      0.55
# BaggingClassifier                  0.54               0.54    None      0.54
# LinearSVC                          0.54               0.54    None      0.55
# LabelSpreading                     0.53               0.53    None      0.53
# LabelPropagation                   0.53               0.53    None      0.53
# ExtraTreeClassifier                0.53               0.53    None      0.53
# Perceptron                         0.51               0.51    None      0.51
# PassiveAggressiveClassifier        0.51               0.50    None      0.51
# DecisionTreeClassifier             0.48               0.49    None      0.48
# NearestCentroid                    0.47               0.47    None      0.47
# GaussianNB                         0.46               0.47    None      0.46
# BernoulliNB                        0.45               0.45    None      0.43
# QuadraticDiscriminantAnalysis      0.43               0.42    None      0.39
# DummyClassifier                    0.35               0.33    None      0.18
#
#                                Time Taken
# Model
# LGBMClassifier                       0.52
# NuSVC                                0.07
# RandomForestClassifier               0.42
# SGDClassifier                        0.02
# ExtraTreesClassifier                 0.28
# KNeighborsClassifier                 0.05
# SVC                                  0.06
# LinearDiscriminantAnalysis           0.02
# LogisticRegression                   0.03
# CalibratedClassifierCV               0.73
# RidgeClassifierCV                    0.02
# RidgeClassifier                      0.02
# AdaBoostClassifier                   0.26
# BaggingClassifier                    0.14
# LinearSVC                            0.18
# LabelSpreading                       0.05
# LabelPropagation                     0.04
# ExtraTreeClassifier                  0.03
# Perceptron                           0.02
# PassiveAggressiveClassifier          0.02
# DecisionTreeClassifier               0.04
# NearestCentroid                      0.01
# GaussianNB                           0.02
# BernoulliNB                          0.01
# QuadraticDiscriminantAnalysis        0.01
# DummyClassifier                      0.03
